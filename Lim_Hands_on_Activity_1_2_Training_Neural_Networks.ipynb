# %% [markdown]
# <a href="https://colab.research.google.com/github/TIPQC-LimSEA/CPE313/blob/main/Lim_Hands_on_Activity_1_2_Training_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Activity 1.2 : Training Neural Networks

# %% [markdown]
# #### Objective(s):
#
# This activity aims to demonstrate how to train neural networks using keras

# %% [markdown]
# #### Intended Learning Outcomes (ILOs):
# * Demonstrate how to build and train neural networks
# * Demonstrate how to evaluate and plot the model using training and validation loss

# %% [markdown]
# #### Resources:
# * Jupyter Notebook
#
# CI Pima Diabetes Dataset
#
# * pima-indians-diabetes.csv

# %% [markdown]
# #### Procedures

# %% [markdown]
# Load the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score, roc_curve, accuracy_score
from sklearn.ensemble import RandomForestClassifier

import seaborn as sns

# %matplotlib inline

# %%
## Import Keras objects for Deep Learning

from keras.models  import Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam, SGD, RMSprop

# %% [markdown]
# Load the dataset

# %%
filepath = "/content/drive/MyDrive/CPE 313-CPE32S3 - Advanced Machine Learning and Deep Learning/Hands-on Activity 2.2 Training Neural Networks/pima-indians-diabetes.csv"
names = ["times_pregnant", "glucose_tolerance_test", "blood_pressure", "skin_thickness", "insulin",
         "bmi", "pedigree_function", "age", "has_diabetes"]
diabetes_df = pd.read_csv(filepath, names=names)

# %% [markdown]
# Check the top 5 samples of the data

# %%
print(diabetes_df.shape)
diabetes_df.sample(5)
# Out:
# (768, 9)
#      times_pregnant  glucose_tolerance_test  blood_pressure  skin_thickness  \
# 130               4                     173              70              14
# 466               0                      74              52              10
# 408               8                     197              74               0
# 628               5                     128              80               0
# 672              10                      68             106              23
#
#      insulin   bmi  pedigree_function  age  has_diabetes
# 130      168  29.7              0.361   33             1
# 466       36  27.8              0.269   22             0
# 408        0  25.9              1.191   39             1
# 628        0  34.6              0.144   45             0
# 672       49  35.5              0.285   47             0

# %%
diabetes_df.dtypes
# Out:
# times_pregnant              int64
# glucose_tolerance_test      int64
# blood_pressure              int64
# skin_thickness              int64
# insulin                     int64
# bmi                       float64
# pedigree_function         float64
# age                         int64
# has_diabetes                int64
# dtype: object

# %%
X = diabetes_df.iloc[:, :-1].values
y = diabetes_df["has_diabetes"].values

# %% [markdown]
# Split the data to Train, and Test (75%, 25%)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=11111)

# %%
np.mean(y), np.mean(1-y)
# Out:
# (np.float64(0.3489583333333333), np.float64(0.6510416666666666))

# %% [markdown]
# Build a single hidden layer neural network using 12 nodes.
# Use the sequential model with single layer network and input shape to 8.

# %% [markdown]
# Normalize the data

# %%
normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# %% [markdown]
# Define the model:
# * Input size is 8-dimensional
# * 1 hidden layer, 12 hidden nodes, sigmoid activation
# * Final layer with one node and sigmoid activation (standard for binary classification)

# %%
model  = Sequential([
    Dense(12, input_shape=(8,), activation="relu"),
    Dense(1, activation="sigmoid")
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# View the model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12)             │           108 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 121 (484.00 B)
#  Trainable params: 121 (484.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train the model
# * Compile the model with optimizer, loss function and metrics
# * Use the fit function to return the run history.

# %%
model.compile(SGD(learning_rate = .003), "binary_crossentropy", metrics=["accuracy"])
run_hist_1 = model.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=200)
# Out:
# Epoch 1/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.6306 - loss: 0.6775 - val_accuracy: 0.6667 - val_loss: 0.6590
# Epoch 2/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6059 - loss: 0.7034 - val_accuracy: 0.6667 - val_loss: 0.6553
# Epoch 3/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6243 - loss: 0.6720 - val_accuracy: 0.6771 - val_loss: 0.6517
# Epoch 4/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6533 - loss: 0.6825 - val_accuracy: 0.6667 - val_loss: 0.6483
# Epoch 5/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6318 - loss: 0.6730 - val_accuracy: 0.6771 - val_loss: 0.6450
# Epoch 6/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6480 - loss: 0.6586 - val_accuracy: 0.6719 - val_loss: 0.6418
# Epoch 7/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6566 - loss: 0.6611 - val_accuracy: 0.6719 - val_loss: 0.6387
# Epoch 8/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6720 - loss: 0.6440 - val_accuracy: 0.6719 - val_loss: 0.6358
# Epoch 9/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6520 - loss: 0.6682 - val_accuracy: 0.6719 - val_loss: 0.6329
# Epoch 10/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6472 - loss: 0.6538 - val_accuracy: 0.6771 - val_loss: 0.6301
# Epoch 11/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6300 - loss: 0.6749 - val_accuracy: 0.6823 - val_loss: 0.6274
# Epoch 12/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6555 - loss: 0.6530 - val_accuracy: 0.6823 - val_loss: 0.6248
# Epoch 13/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6584 - loss: 0.6449 - val_accuracy: 0.6979 - val_loss: 0.6223
# Epoch 14/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.
# Epoch 181/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7688 - loss: 0.4853 - val_accuracy: 0.7812 - val_loss: 0.4968
# Epoch 182/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7733 - loss: 0.4876 - val_accuracy: 0.7812 - val_loss: 0.4967
# Epoch 183/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7738 - loss: 0.4718 - val_accuracy: 0.7917 - val_loss: 0.4965
# Epoch 184/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7880 - loss: 0.4705 - val_accuracy: 0.7917 - val_loss: 0.4963
# Epoch 185/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8010 - loss: 0.4572 - val_accuracy: 0.7917 - val_loss: 0.4962
# Epoch 186/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7604 - loss: 0.4920 - val_accuracy: 0.7917 - val_loss: 0.4961
# Epoch 187/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7783 - loss: 0.4669 - val_accuracy: 0.7917 - val_loss: 0.4959
# Epoch 188/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7540 - loss: 0.4781 - val_accuracy: 0.7917 - val_loss: 0.4958
# Epoch 189/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7747 - loss: 0.4810 - val_accuracy: 0.7917 - val_loss: 0.4956
# Epoch 190/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7951 - loss: 0.4512 - val_accuracy: 0.7917 - val_loss: 0.4955
# Epoch 191/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7730 - loss: 0.4655 - val_accuracy: 0.7917 - val_loss: 0.4953
# Epoch 192/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7842 - loss: 0.4661 - val_accuracy: 0.7917 - val_loss: 0.4952
# Epoch 193/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7866 - loss: 0.4658 - val_accuracy: 0.7917 - val_loss: 0.4951
# Epoch 194/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7737 - loss: 0.4674 - val_accuracy: 0.7917 - val_loss: 0.4949
# Epoch 195/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7798 - loss: 0.4713 - val_accuracy: 0.7917 - val_loss: 0.4948
# Epoch 196/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7948 - loss: 0.4470 - val_accuracy: 0.7865 - val_loss: 0.4947
# Epoch 197/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7672 - loss: 0.4856 - val_accuracy: 0.7865 - val_loss: 0.4946
# Epoch 198/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7715 - loss: 0.4851 - val_accuracy: 0.7865 - val_loss: 0.4945
# Epoch 199/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7552 - loss: 0.4929 - val_accuracy: 0.7865 - val_loss: 0.4943
# Epoch 200/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7827 - loss: 0.4760 - val_accuracy: 0.7865 - val_loss: 0.4942

# %%
## Like we did for the Random Forest, we generate two kinds of predictions
#  One is a hard decision, the other is a probabilitistic score.

y_pred_class_nn_1 = model.predict(X_test_norm)
y_pred_prob_nn_1 = model.predict(X_test_norm)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Let's check out the outputs to get a feel for how keras apis work.
y_pred_class_nn_1[:10]
# Out:
# array([[0.5677518 ],
#        [0.7180304 ],
#        [0.2838469 ],
#        [0.24365593],
#        [0.17890981],
#        [0.4731253 ],
#        [0.06971979],
#        [0.31418598],
#        [0.8781661 ],
#        [0.25076872]], dtype=float32)

# %%
y_pred_prob_nn_1[:10]
# Out:
# array([[0.5677518 ],
#        [0.7180304 ],
#        [0.2838469 ],
#        [0.24365593],
#        [0.17890981],
#        [0.4731253 ],
#        [0.06971979],
#        [0.31418598],
#        [0.8781661 ],
#        [0.25076872]], dtype=float32)

# %% [markdown]
# Create the plot_roc function

# %%
def plot_roc(y_test, y_pred, model_name):
    fpr, tpr, thr = roc_curve(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(fpr, tpr, 'k-')
    ax.plot([0, 1], [0, 1], 'k--', linewidth=.5)  # roc curve for random model
    ax.grid(True)
    ax.set(title='ROC Curve for {} on PIMA diabetes problem'.format(model_name),
           xlim=[-0.01, 1.01], ylim=[-0.01, 1.01])

# %% [markdown]
# Evaluate the model performance and plot the ROC CURVE

# %%
print('accuracy is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_1)))
print('roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_1)))

plot_roc(y_test, y_pred_prob_nn_1, 'NN')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-900058724.py in <cell line: 0>()
# ----> 1 print('accuracy is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_1)))
#       2 print('roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_1)))
#       3
#       4 plot_roc(y_test, y_pred_prob_nn_1, 'NN')
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     225     # Compute accuracy for each possible representation
#     226     y_true, y_pred = attach_unique(y_true, y_pred)
# --> 227     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     228     check_consistent_length(y_true, y_pred, sample_weight)
#     229
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#     105
#     106     if len(y_type) > 1:
# --> 107         raise ValueError(
#     108             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     109                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
#  Plot the training loss and the validation loss over the different epochs and see how it looks

# %%
run_hist_1.history.keys()

# %%
fig, ax = plt.subplots()
ax.plot(run_hist_1.history["loss"],'r', marker='.', label="Train Loss")
ax.plot(run_hist_1.history["val_loss"],'b', marker='.', label="Validation Loss")
ax.legend()

# %% [markdown]
# What is your interpretation about the result of the train and validation loss?

# %% [markdown]
# #type your answer here

# %% [markdown]
# #### Supplementary Activity

# %% [markdown]
# * Build a model with two hidden layers, each with 6 nodes
# * Use the "relu" activation function for the hidden layers, and "sigmoid" for the final layer
# * Use a learning rate of .003 and train for 1500 epochs
# * Graph the trajectory of the loss functions, accuracy on both train and test set
# * Plot the roc curve for the predictions
# * Use different learning rates, numbers of epochs, and network structures.
# * Plot the results of training and validation loss using different learning rates, number of epocgs and network structures
# * Interpret your result

# %% [markdown]
# #### Conclusion

# %% [markdown]
# #type your answer here
